# %% [markdown]
# # Entrenamiento de Modelos: Predicción de Cancelaciones
# Este notebook contiene el flujo de trabajo para entrenar y evaluar el modelo.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score
import pickle

# Aquí deberías cargar el dataset real 'hotel_bookings.csv'
# df = pd.read_csv('hotel_bookings.csv')
print('Notebook listo para ingestar los datos y entrenar el modelo XGBoost.')
